# %%
import duckdb

conn = duckdb.connect(database='madang.db')
conn.sql("create table Customer as select * from 'Customer_madang.csv'")
conn.sql("create table Book as select * from 'Book_madang.csv'")
conn.sql("create table Orders as select * from 'Orders_madang.csv'")
conn.close()

# %%
import duckdb
conn = duckdb.connect(database='madang.db')

# %%
conn.sql("select * from Customer")
# Out:
# ┌────────┬─────────┬─────────────────┬───────────────┐
# │ custid │  name   │     address     │     phone     │
# │ int64  │ varchar │     varchar     │    varchar    │
# ├────────┼─────────┼─────────────────┼───────────────┤
# │      1 │ 박지성  │ 영국 맨체스타   │ 000-5000-0001 │
# │      2 │ 김연아  │ 대한민국 서울   │ 000-6000-0001 │
# │      3 │ 장미란  │ 대한민국 강원도 │ 000-7000-0001 │
# │      4 │ 추신수  │ 미국 클리블랜드 │ 000-8000-0001 │
# │      5 │ 박세리  │ 대한민국 대전   │ NULL          │
# │      6 │ 김도연  │ 인천시 미추홀구 │ 010-1111-1111 │
# └────────┴─────────┴─────────────────┴───────────────┘

# %%
def query(sql, retunrType='df'):
       if retunrType == 'df':
              return conn.execute(sql).df()
       else:
              return conn.execute(sql).fetchall()

#query("select * from Book", "df")
query("select * from Book", "list")
# Out:
# [(1, '축구의 역사', '굿스포츠', 7000),
#  (2, '축구아는 여자', '나무수', 13000),
#  (3, '축구의 이해', '대한미디어', 22000),
#  (4, '골프 바이블', '대한미디어', 35000),
#  (5, '피겨 교본', '굿스포츠', 8000),
#  (6, '역도 단계별기술', '굿스포츠', 6000),
#  (7, '야구의 추억', '이상미디어', 20000),
#  (8, '야구를 부탁해', '이상미디어', 13000),
#  (9, '올림픽 이야기', '삼성당', 7500),
#  (10, 'Olympic Champions', 'Pearson', 13000)]

# %%
conn.execute("select * from Orders").fetchall()
# Out:
# [(1, 1, 1, 6000, datetime.date(2014, 7, 1)),
#  (2, 1, 3, 21000, datetime.date(2014, 7, 3)),
#  (3, 2, 5, 8000, datetime.date(2014, 7, 3)),
#  (4, 3, 6, 6000, datetime.date(2014, 7, 4)),
#  (5, 4, 7, 20000, datetime.date(2014, 7, 5)),
#  (6, 1, 2, 12000, datetime.date(2014, 7, 7)),
#  (7, 4, 8, 13000, datetime.date(2014, 7, 7)),
#  (8, 3, 10, 12000, datetime.date(2014, 7, 8)),
#  (9, 2, 10, 7000, datetime.date(2014, 7, 9)),
#  (10, 3, 8, 13000, datetime.date(2014, 7, 10))]

# %%
conn.sql("select * from Orders")
# Out:
# ┌─────────┬────────┬────────┬───────────┬────────────┐
# │ orderid │ custid │ bookid │ saleprice │ orderdate  │
# │  int64  │ int64  │ int64  │   int64   │    date    │
# ├─────────┼────────┼────────┼───────────┼────────────┤
# │       1 │      1 │      1 │      6000 │ 2014-07-01 │
# │       2 │      1 │      3 │     21000 │ 2014-07-03 │
# │       3 │      2 │      5 │      8000 │ 2014-07-03 │
# │       4 │      3 │      6 │      6000 │ 2014-07-04 │
# │       5 │      4 │      7 │     20000 │ 2014-07-05 │
# │       6 │      1 │      2 │     12000 │ 2014-07-07 │
# │       7 │      4 │      8 │     13000 │ 2014-07-07 │
# │       8 │      3 │     10 │     12000 │ 2014-07-08 │
# │       9 │      2 │     10 │      7000 │ 2014-07-09 │
# │      10 │      3 │      8 │     13000 │ 2014-07-10 │
# ├─────────┴────────┴────────┴───────────┴────────────┤
# │ 10 rows                                  5 columns │
# └────────────────────────────────────────────────────┘

# %%
query("select * from Customer c, Orders o where c.custid = o.custid")
# Out:
#    custid name   address          phone  orderid  custid_1  bookid  saleprice  \
# 0       1  박지성   영국 맨체스타  000-5000-0001        1         1       1       6000
# 1       1  박지성   영국 맨체스타  000-5000-0001        2         1       3      21000
# 2       2  김연아   대한민국 서울  000-6000-0001        3         2       5       8000
# 3       3  장미란  대한민국 강원도  000-7000-0001        4         3       6       6000
# 4       4  추신수  미국 클리블랜드  000-8000-0001        5         4       7      20000
# 5       1  박지성   영국 맨체스타  000-5000-0001        6         1       2      12000
# 6       4  추신수  미국 클리블랜드  000-8000-0001        7         4       8      13000
# 7       3  장미란  대한민국 강원도  000-7000-0001        8         3      10      12000
# 8       2  김연아   대한민국 서울  000-6000-0001        9         2      10       7000
# 9       3  장미란  대한민국 강원도  000-7000-0001       10         3       8      13000
#
#    orderdate
# 0 2014-07-01
# 1 2014-07-03
# 2 2014-07-03
# 3 2014-07-04
# 4 2014-07-05
# 5 2014-07-07
# 6 2014-07-07
# 7 2014-07-08
# 8 2014-07-09
# 9 2014-07-10

# %%
conn.execute("INSERT INTO Customer VALUES (6, '김도연', '인천시 미추홀구', '010-1111-1111')")

# 잘 들어갔는지 확인 (방금 넣은 이름으로 검색)
conn.sql("SELECT * FROM Customer WHERE name = '김도연'").show()
# Out:
# ┌────────┬─────────┬─────────────────┬───────────────┐
# │ custid │  name   │     address     │     phone     │
# │ int64  │ varchar │     varchar     │    varchar    │
# ├────────┼─────────┼─────────────────┼───────────────┤
# │      6 │ 김도연  │ 인천시 미추홀구 │ 010-1111-1111 │
# └────────┴─────────┴─────────────────┴───────────────┘

# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\doyeon\anaconda3\lib\site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in c:\users\doyeon\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in c:\users\doyeon\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\doyeon\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in c:\users\doyeon\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\doyeon\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\doyeon\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\doyeon\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\doyeon\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\doyeon\anaconda3\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\doyeon\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\doyeon\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\doyeon\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\doyeon\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\doyeon\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\doyeon\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\doyeon\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\doyeon\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\doyeon\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\doyeon\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\doyeon\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\doyeon\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\doyeon\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\doyeon\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import duckdb
import pandas as pd
import time

# 1. DuckDB 연결 (read_only=False여야 데이터 입력 가능)
conn = duckdb.connect(database='madang.db', read_only=False)

# 2. 쿼리 실행 함수 (DuckDB 스타일로 변경)
def query(sql):
    return conn.execute(sql).fetchall()

st.title("📚 마당 서점 포스(POS) 시스템")

# 책 목록 미리 가져오기 (콤보박스용)
# DuckDB는 리스트 컴프리헨션으로 간단하게 처리 가능
books_data = conn.execute("select bookid, bookname from Book").fetchall()
# "1, 축구의 역사" 형태로 문자열 만들기
book_options = [f"{row[0]}, {row[1]}" for row in books_data]

# 탭 구성
tab1, tab2 = st.tabs(["🔍 고객 조회", "💳 거래 입력"])

# 변수 초기화
name_input = ""
selected_custid = None # custid를 저장할 변수

# --- 탭 1: 고객 조회 ---
with tab1:
    name_input = st.text_input("고객명 검색")
    
    if name_input:
        # SQL Injection 방지를 위해 f-string 사용 (간단한 버전)
        sql = f"""
            SELECT c.custid, c.name, b.bookname, o.orderdate, o.saleprice 
            FROM Customer c
            JOIN Orders o ON c.custid = o.custid
            JOIN Book b ON o.bookid = b.bookid
            WHERE c.name = '{name_input}'
        """
        
        # 결과가 있는지 확인
        result_df = conn.execute(sql).df()
        
        if not result_df.empty:
            st.write(f"**{name_input}** 님의 거래 내역입니다.")
            st.dataframe(result_df)
            
            # 조회된 고객의 ID를 저장 (거래 입력 탭에서 쓰기 위해)
            selected_custid = result_df['custid'][0]
        else:
            st.warning("해당 이름의 고객이나 거래 내역이 없습니다.")

# --- 탭 2: 거래 입력 ---
with tab2:
    st.header("새로운 주문 입력")
    
    # 고객 정보 표시 (탭 1에서 검색했으면 자동 입력)
    if selected_custid:
        st.success(f"선택된 고객: {name_input} (ID: {selected_custid})")
        target_custid = selected_custid
    else:
        st.info("먼저 '고객 조회' 탭에서 고객을 검색해주세요.")
        target_custid = st.number_input("또는 고객 번호 직접 입력", value=0)

    # 책 선택
    select_book = st.selectbox("구매할 책 선택:", book_options)
    
    # 가격 입력
    price = st.text_input("판매 금액 (원)")

    if st.button('거래 입력'):
        if target_custid > 0 and select_book and price:
            # 1. 데이터 준비
            bookid = select_book.split(",")[0]
            dt = time.strftime('%Y-%m-%d', time.localtime())
            
            # 2. 주문번호 자동 생성 (최대값 + 1)
            # DuckDB에서 결과가 NULL(첫 주문)일 경우 0으로 처리하는 로직 추가
            max_id = conn.execute("SELECT MAX(orderid) FROM Orders").fetchone()[0]
            new_orderid = 1 if max_id is None else max_id + 1
            
            # 3. INSERT 실행
            insert_sql = f"""
                INSERT INTO Orders (orderid, custid, bookid, saleprice, orderdate) 
                VALUES ({new_orderid}, {target_custid}, {bookid}, {price}, '{dt}')
            """
            conn.execute(insert_sql)
            
            st.balloons() # 성공 축하 효과
            st.success(f"주문이 완료되었습니다! (주문번호: {new_orderid})")
            
            # 확인을 위해 방금 넣은 데이터 보여주기
            st.write("입력된 데이터:")
            st.dataframe(conn.execute(f"SELECT * FROM Orders WHERE orderid = {new_orderid}").df())
            
        else:
            st.error("고객 번호와 가격을 정확히 입력해주세요.")
# Out:
# 2025-11-18 19:05:41.809
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\doyeon\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-18 19:05:41.817 Session state does not function when running a script without `streamlit run`

# %%
# Out:
#   Cell In[20], line 1
#     echo "# madang_doyeon" >> README.md
#          ^
# SyntaxError: invalid syntax
